# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
from scipy.stats import randint
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %%
# Loading all the CSV files
file_paths = [
    'Yearly\movies2013.csv',
    'Yearly\movies2014.csv',
    'Yearly\movies2015.csv',
    'Yearly\movies2016.csv',
    'Yearly\movies2017.csv',
    'Yearly\movies2018.csv',
    'Yearly\movies2019.csv',
    'Yearly\movies2020.csv',
    'Yearly\movies2021.csv',
    'Yearly\movies2022.csv',
    'Yearly\movies2023.csv'
 ]



# Reading all CSV files into dataframes
dataframes = [pd.read_csv(file) for file in file_paths]

# Merging all dataframes into a single dataframe and dropping duplicates
TMDB_df = pd.concat(dataframes)
TMDB_df.drop_duplicates(subset=['imdb_id'], keep='first', inplace=True)

# %%
online=pd.read_csv('Yearly\Online 2017 data.csv')
online.rename(columns={'Keywords': 'keywords'}, inplace=True)

def extract_character_names(cast_str):
    try:
        # Convert the string representation of the list of dictionaries into an actual list of dictionaries
        cast_list = ast.literal_eval(cast_str)

        # Extract the character names
        return [cast_member['character'] for cast_member in cast_list]
    except:
        return []

online['cast'] = online['cast'].apply(extract_character_names)

TMDB_df=pd.concat([online,TMDB_df])
TMDB_df.drop_duplicates(subset=['imdb_id'], keep='first', inplace=True)

# %%
TMDB_df[TMDB_df['revenue']!=0]
# Out:
#             id                              belongs_to_collection    budget  \
# 0            1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1            2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2            3                                                NaN   3300000
# 3            4                                                NaN   1200000
# 4            5                                                NaN         0
# ...        ...                                                ...       ...
# 28446   800227                                                NaN         0
# 29447  1187038                                                NaN         6
# 29597  1065835                                                NaN   5404446
# 30336   947650                                                NaN         0
# 31557  1116492                                                NaN      5000
#
#                                                   genres  \
# 0                         [{'id': 35, 'name': 'Comedy'}]
# 1      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                          [{'id': 18, 'name': 'Drama'}]
# 3      [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4      [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                  ...
# 28446                      [{'id': 18, 'name': 'Drama'}]
# 29447  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 29597  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 30336  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 31557  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
#
#                                                 homepage     imdb_id  \
# 0                                                    NaN   tt2637294
# 1                                                    NaN   tt0368933
# 2                      http://sonyclassics.com/whiplash/   tt2582802
# 3                             http://kahaanithefilm.com/   tt1821480
# 4                                                    NaN   tt1380152
# ...                                                  ...         ...
# 28446  http://a24films.com/films/all-dirt-roads-taste...  tt11534720
# 29447                     https://www.pioneerpicture.com  tt27097230
# 29597                                                NaN  tt15654502
# 30336                                                NaN  tt14506102
# 31557                          http://www.trettfilms.com  tt27351080
#
#       original_language                            original_title  \
# 0                    en                    Hot Tub Time Machine 2
# 1                    en  The Princess Diaries 2: Royal Engagement
# 2                    en                                  Whiplash
# 3                    hi                                   Kahaani
# 4                    ko                                      마린보이
# ...                 ...                                       ...
# 28446                en              All Dirt Roads Taste of Salt
# 29447                kn                                   Manduka
# 29597                hi                            The Ladykiller
# 30336                cs            Tonko, Slávka a kúzelné svetlo
# 31557                en                                      Dial
#
#                                                 overview  popularity  ...  \
# 0      When Lou, who has become the "father of the In...    6.575393  ...
# 1      Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2      Under the direction of a ruthless instructor, ...   64.299990  ...
# 3      Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4      Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                  ...         ...  ...
# 28446  Tender caresses and enveloping embraces are po...    6.058000  ...
# 29447  A girl suffering from schizophrenia accidental...    3.045000  ...
# 29597  When a small-town playboy falls in love for a ...    1.700000  ...
# 30336  Tony has been glowing since the day he was bor...    2.102000  ...
# 31557  Dani cares for her ill mother who suddenly die...    1.038000  ...
#
#                                           title  \
# 0                        Hot Tub Time Machine 2
# 1      The Princess Diaries 2: Royal Engagement
# 2                                      Whiplash
# 3                                       Kahaani
# 4                                    Marine Boy
# ...                                         ...
# 28446              All Dirt Roads Taste of Salt
# 29447                                   Manduka
# 29597                            The Ladykiller
# 30336          Tony, Shelly and the Magic Light
# 31557                                      Dial
#
#                                                 keywords  \
# 0      [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1      [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2      [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3      [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                    NaN
# ...                                                  ...
# 28446   ['woman director', 'visual poem', 'mississippi']
# 29447  ['india', 'kannada', 'accidental crime', 'sand...
# 29597  ['mysterious woman', 'erotic thriller', 'suspe...
# 30336                                    ['stop motion']
# 31557       ['psychological thriller', 'phone', 'carer']
#
#                                                     cast  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 28446  ['Charleen McClure', 'Sheila Atim', 'Moses Ing...
# 29447  ['Anjala', 'Madhan', 'Bhushan', 'Mysore raju',...
# 29597  ['Bhumi Pednekar', 'Arjun Kapoor', 'Priyanka B...
# 30336  ['Michael Polák', 'Antonie Baresová', 'Ivana U...
# 31557  ['Olivia Bourne', 'Denise Stephenson', 'Greg L...
#
#                                                     crew   revenue  adult  \
# 0      [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651    NaN
# 1      [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435    NaN
# 2      [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000    NaN
# 3      [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000    NaN
# 4      [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970    NaN
# ...                                                  ...       ...    ...
# 28446                                                NaN     41000  False
# 29447                                                NaN        10  False
# 29597                                                NaN       456  False
# 30336                                                NaN    191018  False
# 31557                                                NaN      5000  False
#
#                           backdrop_path  video vote_average vote_count
# 0                                   NaN    NaN          NaN        NaN
# 1                                   NaN    NaN          NaN        NaN
# 2                                   NaN    NaN          NaN        NaN
# 3                                   NaN    NaN          NaN        NaN
# 4                                   NaN    NaN          NaN        NaN
# ...                                 ...    ...          ...        ...
# 28446  /p65KvZIFrlYxB3LZU2e5WtYvmfZ.jpg  False          0.0        0.0
# 29447  /oXLzPSTw5YoAUU7XcXf88BjICq2.jpg  False          0.0        0.0
# 29597  /eyDx5sUQscDqDC3PdRbsBNH3BxB.jpg  False          0.0        0.0
# 30336  /rFdlSLjaf6qrGChWr9gje6eTcbf.jpg  False          0.0        0.0
# 31557  /6mkQa7QVIC5LLx7tJr7FCgVbyc3.jpg  False          0.0        0.0
#
# [8266 rows x 28 columns]

# %%
MOJO_df = pd.read_csv('gross_earnings_domestic_2013-2023.csv').rename(columns={'daily earnings':'gross_earnings_domestic'})
MOJO_df
# Out:
#                                            movie  gross_earnings_domestic  \
# 0                                            '71                1270847.0
# 1                                            '83                4055672.0
# 2     '85: The Greatest Team in Football History                 124573.0
# 3                            10 Cloverfield Lane               72082998.0
# 4                                      10.000 Km                  12423.0
# ...                                          ...                      ...
# 3914                                    Zootopia              341268248.0
# 3915                                   iMordecai                 139887.0
# 3916                  xXx: Return of Xander Cage               44898413.0
# 3917                           ¡Que viva México!                 161222.0
# 3918                              ¿Y cómo es él?                1500636.0
#
#       theatres  earnings_per_theatre
# 0       3681.0            345.245042
# 1       8605.0            471.315747
# 2        236.0            527.851695
# 3     117138.0            615.368181
# 4         77.0            161.337662
# ...        ...                   ...
# 3914  271096.0           1258.846490
# 3915     870.0            160.789655
# 3916   82488.0            544.302359
# 3917    1020.0            158.060784
# 3918    6174.0            243.057337
#
# [3919 rows x 4 columns]

# %%
#Check # of rows that are the same movie before merging
MOJO_set = (set(MOJO_df["movie"].to_list()))
TMDB_set = set((TMDB_df["title"].to_list()))
print(f'Total movies in both dataframes: {len(MOJO_set.intersection(TMDB_set))}')
# Out:
# Total movies in both dataframes: 3364

# %%
# Create sets of movie names from both DataFrames
movie_names_df1 = set(MOJO_set)
movie_names_df2 = set(TMDB_set)

# Find movie names that are unique to each DataFrame
unique_to_df1 = movie_names_df1 - movie_names_df2
unique_to_df2 = movie_names_df2 - movie_names_df1

# Print the movie names unique to each DataFrame
print("Movies unique to MOJO_set:", unique_to_df1)
# Out:
# Movies unique to MOJO_set: {'The Discreet Charm of the Bourgeoisie', "It's a Wonderful Life", 'Saving Private Ryan', 'The Apu Trilogy', 'The Giant Spider Invasion', 'Pavarotti', 'How the Grinch Stole Christmas', 'From the East', "L'Arracheuse de temps", 'Wa-shoku Dream: Beyond Sushi', 'Mid90s', 'ParaNorman', 'Seed: The Untold Story', 'Stavisky', 'Buttons, A New Musical Film', 'Parallel Policy', 'Raymonda: Bolshoi Ballet', 'The Grandmother', 'Shift: The Ragbrai Documentary', 'Gone with the Wind', 'Pom Poko', 'Beauty and the Beholder', 'Borg vs. McEnroe', 'Hotel Transylvania', 'Argus Limited', 'Steel Magnolias', "The Emperor's New Groove", 'High Tech, Low Life', 'Tea With the Dames', 'Le Jour Se Leve', 'Terminator 2: Judgment Day', 'Mother!', 'The Girlfriends', 'Tanu Weds Manu Returns', 'Ernest & Celestine', 'Women Like Us', "Fate/stay night [Heaven's Feel] I. presage flower", 'Starbuck', 'Rossini: Semiramide', 'One Piece Film: Gold', 'Free Angela and All Political Prisoners', 'Samurai Cop', 'Mahogany Sunrise', 'Puccini: Turandot', 'The Boy and the World', 'Kai Po Che', 'Lignes de fuite', 'Gabo: The Creation of Gabriel Garcia Marquez', 'Leaving Home, Coming Home: A Portrait of Robert Frank', 'The Four Sisters', 'Lincoln', 'Patterns of Evidence: Moses Controversy', 'Gamestop: Rise of the Players', 'Die Hard', 'Lumpia with a Vengeance', 'Gori Tere Pyaar Mein!', 'Cinco de Mayo, La Batalla', "I'll Push You: A Real-Life Inspiration", 'Mazinger Z: INFINITY', 'Andrei Rublev', 'Daliland', 'Sidemen: Long Road to Glory', 'Bolshoi Ballet: The Sleeping Beauty', 'Escape Fire: The Fight to Rescue American Healthcare', 'Winnie Mandela', 'Heat and Dust', 'The Gender Card Flip', 'Silver Linings Playbook', 'Saga of Tanya the Evil - The Movie', 'Bullitt', 'Lawrence of Arabia', 'When You Read This Letter', 'The Lion in Winter', 'Demi-soeur', 'Best F(r)iends Volume Two', 'Metallica Through the Never', 'Nostalgia for the Light', 'Coraline', 'Octaman', "Donizetti: L'Elisir d'Amore", 'Cassadaga', '3 Idiots', '2001: A Space Odyssey', 'The Grateful Dead Meet-Up 2018', 'Countdown to Canelo vs. Chavez Jr.', 'One Piece: Stampede', 'Out in the Dark', 'A Cop', 'A Chiara', 'Making the Five Heartbeats', 'A Brilliant Young Mind', 'Sunset Blvd.', 'Little Eggs: An African Rescue', 'IN OUR HANDS: Battle for Jerusalem', 'Supermensch', 'The Twilight Saga: Breaking Dawn - Part 2', "A Father's Heart", 'Shanghai', 'Once Upon a Time in Hollywood', "Howl's Moving Castle", 'Father Stu: Reborn', 'Puccini: Madama Butterfly', 'Gladiators of Rome', 'Green is Gold', 'The Tale of The Princess Kaguya', 'The Philadelphia Story', 'Under the Sea 3D', 'Bob the Gambler', 'Bharath Ane Nenu', 'I Love You, I Love You', 'Chris Brown: Welcome To My Life', 'Grave of the Fireflies', 'Star Wars: Episode V - The Empire Strikes Back', 'The Wicker Man', 'Pokémon: Detective Pikachu', 'Meet Me in St. Louis', 'Russ Taff: I Still Believe', "Mary and the Witch's Flower", 'UFC 286', 'The Boxcar Children - Surprise Island', "Kirk Cameron's Saving Christmas", 'Across the Universe', 'Is It Wrong to Try to Pick Up Girls in a Dungeon - Arrow of the Orion', 'Deontay Wilder vs. Tyson Fury', "The Rabbi's Cat", 'The Great Flood', 'Doctor Who: Logopolis', "National Lampoon's Christmas Vacation", 'The Endless Summer', 'The Divine Protector: Master Salt Begins', 'The Santa Clause', 'I Can', 'ABCD (Any Body Can Dance)', 'The Riot and the Dance', 'BANDSTAND: The Broadway Musical on Screen', 'Love Live! Sunshine!! The School Idol Movie: Over The Rainbow', 'Kill Devil Hills', 'The Last Day of August', 'Spider-Man: Far from Home', 'Mamma Mia!', 'Brotherhood of the Wolf', 'Christ Stopped at Eboli', 'Bolshoi Ballet: Le Corsaire', 'Margaret Atwood: Live in Cinemas', 'Hallelujah: Leonard Cohen, a Journey, a Song', 'Bolshoi Ballet: Swan Lake', 'Far From the Tree', 'Tod@s caen', "Fate/stay night [Heaven's Feel] III. spring song", 'Canelo Alvarez vs. Daniel Jacobs', 'Shadow in the Cloud', 'Attack on Titan: Part 2', 'The Chos ...

# %%
import json

# Define a function to extract the names of the production companies and create a comma-separated string
def extract_production_company_names(production_companies):
    # Check if the production companies data is a string and convert to a list if necessary
    if isinstance(production_companies, str):
        try:
            production_companies = json.loads(production_companies.replace("'", "\""))
        except json.decoder.JSONDecodeError:
            return None
    # Extract the names of the production companies
    if isinstance(production_companies, list):
        company_names = [company['name'] for company in production_companies if 'name' in company]
        return ', '.join(company_names)  # Use ', ' to separate with a comma and space
    return None

# Apply the function to the 'production_companies' column
TMDB_df['production_companies'] = TMDB_df['production_companies'].apply(extract_production_company_names)

# %%
TMDB_df[TMDB_df['revenue']!=0]
# Out:
#             id                              belongs_to_collection    budget  \
# 0            1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1            2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2            3                                                NaN   3300000
# 3            4                                                NaN   1200000
# 4            5                                                NaN         0
# ...        ...                                                ...       ...
# 28446   800227                                                NaN         0
# 29447  1187038                                                NaN         6
# 29597  1065835                                                NaN   5404446
# 30336   947650                                                NaN         0
# 31557  1116492                                                NaN      5000
#
#                                                   genres  \
# 0                         [{'id': 35, 'name': 'Comedy'}]
# 1      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                          [{'id': 18, 'name': 'Drama'}]
# 3      [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4      [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                  ...
# 28446                      [{'id': 18, 'name': 'Drama'}]
# 29447  [{'id': 9648, 'name': 'Mystery'}, {'id': 80, '...
# 29597  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 30336  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 31557  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
#
#                                                 homepage     imdb_id  \
# 0                                                    NaN   tt2637294
# 1                                                    NaN   tt0368933
# 2                      http://sonyclassics.com/whiplash/   tt2582802
# 3                             http://kahaanithefilm.com/   tt1821480
# 4                                                    NaN   tt1380152
# ...                                                  ...         ...
# 28446  http://a24films.com/films/all-dirt-roads-taste...  tt11534720
# 29447                     https://www.pioneerpicture.com  tt27097230
# 29597                                                NaN  tt15654502
# 30336                                                NaN  tt14506102
# 31557                          http://www.trettfilms.com  tt27351080
#
#       original_language                            original_title  \
# 0                    en                    Hot Tub Time Machine 2
# 1                    en  The Princess Diaries 2: Royal Engagement
# 2                    en                                  Whiplash
# 3                    hi                                   Kahaani
# 4                    ko                                      마린보이
# ...                 ...                                       ...
# 28446                en              All Dirt Roads Taste of Salt
# 29447                kn                                   Manduka
# 29597                hi                            The Ladykiller
# 30336                cs            Tonko, Slávka a kúzelné svetlo
# 31557                en                                      Dial
#
#                                                 overview  popularity  ...  \
# 0      When Lou, who has become the "father of the In...    6.575393  ...
# 1      Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2      Under the direction of a ruthless instructor, ...   64.299990  ...
# 3      Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4      Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                  ...         ...  ...
# 28446  Tender caresses and enveloping embraces are po...    6.058000  ...
# 29447  A girl suffering from schizophrenia accidental...    3.045000  ...
# 29597  When a small-town playboy falls in love for a ...    1.700000  ...
# 30336  Tony has been glowing since the day he was bor...    2.102000  ...
# 31557  Dani cares for her ill mother who suddenly die...    1.038000  ...
#
#                                           title  \
# 0                        Hot Tub Time Machine 2
# 1      The Princess Diaries 2: Royal Engagement
# 2                                      Whiplash
# 3                                       Kahaani
# 4                                    Marine Boy
# ...                                         ...
# 28446              All Dirt Roads Taste of Salt
# 29447                                   Manduka
# 29597                            The Ladykiller
# 30336          Tony, Shelly and the Magic Light
# 31557                                      Dial
#
#                                                 keywords  \
# 0      [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1      [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2      [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3      [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                    NaN
# ...                                                  ...
# 28446   ['woman director', 'visual poem', 'mississippi']
# 29447  ['india', 'kannada', 'accidental crime', 'sand...
# 29597  ['mysterious woman', 'erotic thriller', 'suspe...
# 30336                                    ['stop motion']
# 31557       ['psychological thriller', 'phone', 'carer']
#
#                                                     cast  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 28446  ['Charleen McClure', 'Sheila Atim', 'Moses Ing...
# 29447  ['Anjala', 'Madhan', 'Bhushan', 'Mysore raju',...
# 29597  ['Bhumi Pednekar', 'Arjun Kapoor', 'Priyanka B...
# 30336  ['Michael Polák', 'Antonie Baresová', 'Ivana U...
# 31557  ['Olivia Bourne', 'Denise Stephenson', 'Greg L...
#
#                                                     crew   revenue  adult  \
# 0      [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651    NaN
# 1      [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435    NaN
# 2      [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000    NaN
# 3      [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000    NaN
# 4      [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970    NaN
# ...                                                  ...       ...    ...
# 28446                                                NaN     41000  False
# 29447                                                NaN        10  False
# 29597                                                NaN       456  False
# 30336                                                NaN    191018  False
# 31557                                                NaN      5000  False
#
#                           backdrop_path  video vote_average vote_count
# 0                                   NaN    NaN          NaN        NaN
# 1                                   NaN    NaN          NaN        NaN
# 2                                   NaN    NaN          NaN        NaN
# 3                                   NaN    NaN          NaN        NaN
# 4                                   NaN    NaN          NaN        NaN
# ...                                 ...    ...          ...        ...
# 28446  /p65KvZIFrlYxB3LZU2e5WtYvmfZ.jpg  False          0.0        0.0
# 29447  /oXLzPSTw5YoAUU7XcXf88BjICq2.jpg  False          0.0        0.0
# 29597  /eyDx5sUQscDqDC3PdRbsBNH3BxB.jpg  False          0.0        0.0
# 30336  /rFdlSLjaf6qrGChWr9gje6eTcbf.jpg  False          0.0        0.0
# 31557  /6mkQa7QVIC5LLx7tJr7FCgVbyc3.jpg  False          0.0        0.0
#
# [8266 rows x 28 columns]

# %%
import missingno as msno
msno.matrix(TMDB_df[TMDB_df['revenue']!=0])
# Out:
# <Axes: >

# %%
MOJO_df = pd.read_csv('gross_earnings_domestic_2013-2023.csv').rename(columns={'daily earnings':'gross_earnings_domestic'})
MOJO_df
# Out:
#                                            movie  gross_earnings_domestic  \
# 0                                            '71                1270847.0
# 1                                            '83                4055672.0
# 2     '85: The Greatest Team in Football History                 124573.0
# 3                            10 Cloverfield Lane               72082998.0
# 4                                      10.000 Km                  12423.0
# ...                                          ...                      ...
# 3914                                    Zootopia              341268248.0
# 3915                                   iMordecai                 139887.0
# 3916                  xXx: Return of Xander Cage               44898413.0
# 3917                           ¡Que viva México!                 161222.0
# 3918                              ¿Y cómo es él?                1500636.0
#
#       theatres  earnings_per_theatre
# 0       3681.0            345.245042
# 1       8605.0            471.315747
# 2        236.0            527.851695
# 3     117138.0            615.368181
# 4         77.0            161.337662
# ...        ...                   ...
# 3914  271096.0           1258.846490
# 3915     870.0            160.789655
# 3916   82488.0            544.302359
# 3917    1020.0            158.060784
# 3918    6174.0            243.057337
#
# [3919 rows x 4 columns]

# %%
#Check # of rows that are the same movie before merging
MOJO_set = (set(MOJO_df["movie"].to_list()))
TMDB_set = set((TMDB_df["title"].to_list()))
print(f'Total movies in both dataframes: {len(MOJO_set.intersection(TMDB_set))}')
# Out:
# Total movies in both dataframes: 3364

# %%
merged_df = pd.merge(MOJO_df,TMDB_df,left_on='movie',right_on='title',how='inner')
merged_df.drop_duplicates(subset=['imdb_id'], keep='first', inplace=True)

# %%
msno.matrix(merged_df[merged_df['revenue']!=0])
# Out:
# <Axes: >

# %%
merged_df.drop(columns=['belongs_to_collection','poster_path','status','tagline','crew','adult','backdrop_path','video'], inplace=True)

# %%
msno.matrix(merged_df[merged_df['revenue']!=0])
# Out:
# <Axes: >

# %%
final_df=merged_df[merged_df['revenue']!=0]

# %%
final_df.columns
# Out:
# Index(['movie', 'gross_earnings_domestic', 'theatres', 'earnings_per_theatre',
#        'id', 'budget', 'genres', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'title', 'keywords', 'cast', 'revenue', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
final_df['cast']
# Out:
# 0                                                      []
# 1                                                      []
# 3       ['Luke Evans', 'Kelly Reilly', 'Noel Clarke', ...
# 4       ['Chris Hemsworth', 'Michael Shannon', 'Michae...
# 5       ['Chiwetel Ejiofor', 'Michael Fassbender', "Lu...
#                               ...
# 5629    ['Woody Harrelson', 'Jesse Eisenberg', 'Emma S...
# 5630    ['Ben Stiller', 'Owen Wilson', 'Will Ferrell',...
# 5631                                                   []
# 5633    ['Vin Diesel', 'Donnie Yen', 'Ruby Rose', 'Ton...
# 5634    ['Damián Alcázar', 'Alfonso Herrera', 'Joaquín...
# Name: cast, Length: 2258, dtype: object

# %%
import ast

def convert_date_string_to_datetime(date_string):
    try:
        return pd.to_datetime(date_string, errors='coerce')
    except:
        return None

def extract_countries(production_countries_str):
    try:
        # Convert the string representation of the list of dictionaries into an actual list of dictionaries
        production_countries_list = ast.literal_eval(production_countries_str)

        # Extract the country names
        return [country['name'] for country in production_countries_list]
    except:
        return []

def extract_languages(spoken_languages_str):
    try:
        # Convert the string representation of the list of dictionaries into an actual list of dictionaries
        spoken_languages_list = ast.literal_eval(spoken_languages_str)

        # Extract the language names
        return [language.get('name', language.get('english_name', 'Unknown')) for language in spoken_languages_list]
    except:
        return []
def extract_keywords(keywords_str):
    try:
        # Attempt to interpret the string as a list
        keywords_list = ast.literal_eval(keywords_str)

        # Check if the first element of the list is a dictionary
        if isinstance(keywords_list, list) and keywords_list and isinstance(keywords_list[0], dict):
            # Extract the keyword names from dictionaries
            return [keyword['name'] for keyword in keywords_list]
        elif isinstance(keywords_list, list):
            # The list already contains keyword names as strings
            return keywords_list
        else:
            return []
    except:
        return []


def get_genres(x):
    if pd.isna(x):
        return x
    elif '[' in x:
        genres_list = []
        x = x.replace("'", '"')
        for genre_dict in json.loads(x):
            genres_list.append(genre_dict['name'])
        return genres_list
    else:
        return [x]


def spoken_languages(data):
    if pd.isna(data):
        return None  # Return None for NaN values
    # Replace single-quotes with double-quotes and parse as JSON
    data = data.replace("'", '"')
    language_list = json.loads(data)
    result = [f"[{item['iso_639_1']}]" for item in language_list]
    return result

# %%
final_df['genres'] = final_df['genres'].apply(get_genres)
final_df['spoken_languages'] = final_df['spoken_languages'].apply(extract_languages)
final_df['production_countries'] = final_df['production_countries'].apply(extract_countries)
final_df['release_date'] = pd.to_datetime(final_df['release_date'], errors='coerce')
final_df['keywords'] = final_df['keywords'].apply(extract_keywords)
# Out:
# <ipython-input-24-f5e5eed07237>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['genres'] = final_df['genres'].apply(get_genres)
# <ipython-input-24-f5e5eed07237>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['spoken_languages'] = final_df['spoken_languages'].apply(extract_languages)
# <ipython-input-24-f5e5eed07237>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['production_countries'] = final_df['production_countries'].apply(extract_countries)
# <ipython-input-24-f5e5eed07237>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['release_date'] = pd.to_datetime(final_df['release_date'], errors='coerce')
# <ipython-input-24-f5e5eed07237>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['keywords'] = final_df['keywords'].apply(extract_keywords)

# %%
final_df
# Out:
#                            movie  gross_earnings_domestic  theatres  \
# 0                            '71                1270847.0    3681.0
# 1            10 Cloverfield Lane               72082998.0  117138.0
# 3                          10x10                   2263.0      70.0
# 4                      12 Strong               45500164.0   88991.0
# 5               12 Years a Slave               56634802.0  110810.0
# ...                          ...                      ...       ...
# 5629      Zombieland: Double Tap               73123082.0  110151.0
# 5630                 Zoolander 2               28848693.0   67641.0
# 5631                    Zootopia              341268248.0  271096.0
# 5633  xXx: Return of Xander Cage               44898413.0   82488.0
# 5634           ¡Que viva México!                 161222.0    1020.0
#
#       earnings_per_theatre      id     budget  \
# 0               345.245042    2848          0
# 1               615.368181    1413   15000000
# 3                32.328571  505177          0
# 4               511.289501  429351   35000000
# 5               511.098294   76203   20000000
# ...                    ...     ...        ...
# 5629            663.844014  338967   42000000
# 5630            426.497139  329833   50000000
# 5631           1258.846490     735  150000000
# 5633            544.302359   47971   85000000
# 5634            158.060784  868985          0
#
#                                       genres  \
# 0             [Thriller, Action, Drama, War]
# 1         [Thriller, Science Fiction, Drama]
# 3                                 [Thriller]
# 4              [War, Drama, Action, History]
# 5                           [Drama, History]
# ...                                      ...
# 5629                        [Comedy, Horror]
# 5630             [Comedy, Adventure, Action]
# 5631  [Animation, Adventure, Family, Comedy]
# 5633              [Action, Adventure, Crime]
# 5634                         [Drama, Comedy]
#
#                                          homepage     imdb_id  \
# 0                                             NaN   tt2614684
# 1               http://www.10cloverfieldlane.com/   tt1179933
# 3                                             NaN   tt6210996
# 4                       https://12strongmovie.com   tt1413492
# 5     http://www.foxsearchlight.com/12yearsaslave   tt2024544
# ...                                           ...         ...
# 5629                  https://www.zombieland.com/   tt1560220
# 5630                    http://www.zoolander.com/   tt1608290
# 5631            http://movies.disney.com/zootopia   tt2948356
# 5633                                          NaN   tt1293847
# 5634  https://quevivamexico.com.mx/index_eng.html  tt22185848
#
#      original_language  ...                        production_countries  \
# 0                   en  ...                            [United Kingdom]
# 1                   en  ...                  [United States of America]
# 3                   en  ...                            [United Kingdom]
# 4                   en  ...                  [United States of America]
# 5                   en  ...  [United States of America, United Kingdom]
# ...                ...  ...                                         ...
# 5629                en  ...                  [United States of America]
# 5630                en  ...                  [United States of America]
# 5631                en  ...                  [United States of America]
# 5633                en  ...   [Canada, China, United States of America]
# 5634                es  ...                                    [Mexico]
#
#      release_date  runtime spoken_languages                       title  \
# 0      2014-10-10     99.0        [English]                         '71
# 1      2016-03-10    103.0        [English]         10 Cloverfield Lane
# 3      2018-04-13     86.0        [English]                       10x10
# 4      2018-01-18    130.0        [English]                   12 Strong
# 5      2013-10-18    134.0        [English]            12 Years a Slave
# ...           ...      ...              ...                         ...
# 5629   2019-10-09     99.0        [English]      Zombieland: Double Tap
# 5630   2016-02-06    100.0        [English]                 Zoolander 2
# 5631   2016-02-11    108.0        [English]                    Zootopia
# 5633   2017-01-13    107.0        [English]  xXx: Return of Xander Cage
# 5634   2023-03-23    192.0        [Español]           ¡Que viva México!
#
#                                                keywords  \
# 0     [riot, war, british, survival, soldier, ira, e...
# 1     [kidnapping, bunker, paranoia, basement, survi...
# 3                                 [kidnapping, revenge]
# 4     [cia, based on novel or book, afghanistan, bas...
# 5     [slavery, plantation, based on memoir or autob...
# ...                                                 ...
# 5629  [marriage proposal, the white house, gore, roa...
# 5630  [fashion designer, sequel, fashion, male model...
# 5631  [fox, prejudice, conspiracy, urban, female pro...
# 5633  [airplane, tattoo, spy, extreme sports, parach...
# 5634                                                 []
#
#                                                    cast     revenue  \
# 0                                                    []     1625847
# 1                                                    []   108286421
# 3     ['Luke Evans', 'Kelly Reilly', 'Noel Clarke', ...       68260
# 4     ['Chris Hemsworth', 'Michael Shannon', 'Michae...    67450815
# 5     ['Chiwetel Ejiofor', 'Michael Fassbender', "Lu...   187000000
# ...                                                 ...         ...
# 5629  ['Woody Harrelson', 'Jesse Eisenberg', 'Emma S...   122801777
# 5630  ['Ben Stiller', 'Owen Wilson', 'Will Ferrell',...    56722693
# 5631                                                 []  1023784195
# 5633  ['Vin Diesel', 'Donnie Yen', 'Ruby Rose', 'Ton...   346147658
# 5634  ['Damián Alcázar', 'Alfonso Herrera', 'Joaquín...     4155903
#
#      vote_average vote_count
# 0             NaN        NaN
# 1             NaN        NaN
# 3           5.247      508.0
# 4           6.278     2730.0
# 5           7.946    10695.0
# ...           ...        ...
# 5629        6.951     5257.0
# 5630        4.891     2101.0
# 5631          NaN        NaN
# 5633        6.139     8583.0
# 5634        7.299      137.0
#
# [2258 rows x 24 columns]

# %%
tomato=pd.read_csv('all_scores.csv')
finalmato_df = pd.merge(tomato,final_df,left_on='Movie',right_on='title',how='inner')

# %%
finalmato_df.columns
# Out:
# Index(['Movie', 'Specific Rotten Tomato Score', 'movie',
#        'gross_earnings_domestic', 'theatres', 'earnings_per_theatre', 'id',
#        'budget', 'genres', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'title', 'keywords', 'cast', 'revenue', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
finalmato_df
# Out:
#                                Movie  Specific Rotten Tomato Score  \
# 0              Jack the Giant Slayer                          52.0
# 1             A Good Day to Die Hard                          15.0
# 2     Hansel & Gretel: Witch Hunters                          16.0
# 3                    A Haunted House                           8.0
# 4                               Mama                          64.0
# ...                              ...                           ...
# 2237                  Wreck-It Ralph                          87.0
# 2238            You Hurt My Feelings                          94.0
# 2239      You Were Never Really Here                          89.0
# 2240                Zero Dark Thirty                          91.0
# 2241               ¡Que viva México!                          29.0
#
#                                movie  gross_earnings_domestic  theatres  \
# 0              Jack the Giant Slayer               65187603.0  117248.0
# 1             A Good Day to Die Hard               67349198.0  101927.0
# 2     Hansel & Gretel: Witch Hunters               55703475.0  106896.0
# 3                    A Haunted House               40041683.0   66153.0
# 4                               Mama               71628180.0  102378.0
# ...                              ...                      ...       ...
# 2237                  Wreck-It Ralph               10826687.0   40453.0
# 2238            You Hurt My Feelings                4830789.0   19453.0
# 2239      You Were Never Really Here                2528078.0    5887.0
# 2240                Zero Dark Thirty               94217382.0  131263.0
# 2241               ¡Que viva México!                 161222.0    1020.0
#
#       earnings_per_theatre      id     budget  \
# 0               555.980511     928  195000000
# 1               660.759151   47964   92000000
# 2               521.099714    1467   50000000
# 3               605.288997  139038    2500000
# 4               699.644260     875   15000000
# ...                    ...     ...        ...
# 2237            267.636195    1393  165000000
# 2238            248.331311  890215          0
# 2239            429.434007  398181          0
# 2240            717.775626    2243   40000000
# 2241            158.060784  868985          0
#
#                                       genres  \
# 0                  [Action, Family, Fantasy]
# 1                         [Action, Thriller]
# 2                  [Fantasy, Horror, Action]
# 3                           [Comedy, Horror]
# 4                                   [Horror]
# ...                                      ...
# 2237  [Family, Animation, Comedy, Adventure]
# 2238                [Comedy, Drama, Romance]
# 2239                [Crime, Drama, Thriller]
# 2240              [Thriller, Drama, History]
# 2241                         [Drama, Comedy]
#
#                                              homepage  ...  \
# 0            http://jackthegiantkiller.warnerbros.com  ...
# 1                        http://www.diehardmovie.com/  ...
# 2                http://www.hanselandgretelmovie.com/  ...
# 3                                                 NaN  ...
# 4                           http://www.mamamovie.com/  ...
# ...                                               ...  ...
# 2237              http://disney.go.com/wreck-it-ralph  ...
# 2238  https://a24films.com/films/you-hurt-my-feelings  ...
# 2239             https://www.amazon.com/dp/B0797CB8H4  ...
# 2240        http://www.zerodarkthirty-movie.com/site/  ...
# 2241      https://quevivamexico.com.mx/index_eng.html  ...
#
#                                    production_countries release_date runtime  \
# 0                            [United States of America]   2013-02-27   114.0
# 1                            [United States of America]   2013-02-06    98.0
# 2                   [United States of America, Germany]   2013-01-17    88.0
# 3                            [United States of America]   2013-01-11    86.0
# 4                                       [Spain, Canada]   2013-01-17   100.0
# ...                                                 ...          ...     ...
# 2237                         [United States of America]   2012-11-01   108.0
# 2238                         [United States of America]   2023-05-26    93.0
# 2239  [United Kingdom, United States of America, Fra...   2017-11-08    89.0
# 2240                         [United States of America]   2012-12-19   157.0
# 2241                                           [Mexico]   2023-03-23   192.0
#
#         spoken_languages                           title  \
# 0              [English]           Jack the Giant Slayer
# 1     [English, Pусский]          A Good Day to Die Hard
# 2              [English]  Hansel & Gretel: Witch Hunters
# 3              [English]                 A Haunted House
# 4              [English]                            Mama
# ...                  ...                             ...
# 2237           [English]                  Wreck-It Ralph
# 2238           [English]            You Hurt My Feelings
# 2239           [English]      You Were Never Really Here
# 2240  [English, العربية]                Zero Dark Thirty
# 2241           [Español]               ¡Que viva México!
#
#                                                keywords  \
# 0                          [based on fairy tale, giant]
# 1     [cia, escape, bomb, courthouse, agent, rogue, ...
# 2     [witch, black magic, steampunk, good vs evil, ...
# 3     [ghostbuster, haunted house, parody, crude hum...
# 4                                 [supernatural horror]
# ...                                                 ...
# 2237  [support group, product placement, bullying, r...
# 2238  [new york city, husband wife relationship, the...
# 2239  [hotel, new york city, post-traumatic stress d...
# 2240  [assassination, cia, hotel, terrorist, prisone...
# 2241                                                 []
#
#                                                    cast    revenue  \
# 0                                                    []  197687603
# 1     ['Bruce Willis', 'Jai Courtney', 'Sebastian Ko...  304654182
# 2                                                    []  224803475
# 3     ['Marlon Wayans', 'Essence Atkins', 'Nick Swar...   60141683
# 4                                                    []  146497771
# ...                                                 ...        ...
# 2237                                                 []  471222889
# 2238  ['Julia Louis-Dreyfus', 'Tobias Menzies', 'Mic...    5000000
# 2239  ['Joaquin Phoenix', 'Judith Roberts', 'Ekateri...   10891281
# 2240                                                 []  132820716
# 2241  ['Damián Alcázar', 'Alfonso Herrera', 'Joaquín...    4155903
#
#       vote_average vote_count
# 0              NaN        NaN
# 1            5.328     6099.0
# 2              NaN        NaN
# 3            5.869     1732.0
# 4              NaN        NaN
# ...            ...        ...
# 2237           NaN        NaN
# 2238         6.500       72.0
# 2239         6.557     2589.0
# 2240           NaN        NaN
# 2241         7.299      137.0
#
# [2242 rows x 26 columns]

# %%
youtube=pd.read_csv('movie_engagement_data.csv')

# %%
youtube
# Out:
#                       MovieTitle  \
# 0                            '71
# 1            10 Cloverfield Lane
# 2                          10x10
# 3                      12 Strong
# 4               12 Years a Slave
# ...                          ...
# 2255      Zombieland: Double Tap
# 2256                 Zoolander 2
# 2257                    Zootopia
# 2258  xXx: Return of Xander Cage
# 2259           ¡Que viva México!
#
#                                     YouTube Video Title YouTube Video ID  \
# 0     &#39;71 Official Trailer #1 (2015) - Jack O&#3...      J-BaKfl1Ms4
# 1     10 Cloverfield Lane Official Trailer #1 (2016)...      saHzng8fxLs
# 2     10X10 Official Trailer (2018) Luke Evans, Kell...      zV1eUEPEPPM
# 3                          12 STRONG - Official Trailer      -Denciie5oA
# 4              12 YEARS A SLAVE - Official Trailer (HD)      z02Ie8wKKRg
# ...                                                 ...              ...
# 2255     ZOMBIELAND: DOUBLE TAP - Official Trailer (HD)      ZlW9yhUKlkQ
# 2256    Zoolander 2 Trailer (2016) - Paramount Pictures      4CL4LNWHegk
# 2257  Zootopia - Try Everything By Shakira (Music Vi...      LnSYihRoGA4
# 2258  xXx: Return of Xander Cage - Trailer (2017) - ...      -ziu6JzJTZ0
# 2259                ¡Que Viva México! - Tráiler Oficial      DQ0UqBQ_AII
#
#           Views   Likes  Comments  \
# 0       1808230    5232       538
# 1      11549803   44246      6538
# 2        868257    1690       156
# 3      18053617  120913      6949
# 4       8396503   39660      4485
# ...         ...     ...       ...
# 2255   21061362  319899     15236
# 2256   22525051   87996      8316
# 2257  202560250  501389         0
# 2258   15261034   15765      1004
# 2259    1877685   14536      2243
#
#                                         Top 10 Comments
# 0     Jack o' Connell is quickly becoming that actor...
# 1     Just saw this gem. You gotta love John Goodman...
# 2     jesus... Luke evans. I really hope he gets oth...
# 3     The movie could have ended earlier if he broug...
# 4     This movie was one of the most moving, emotion...
# ...                                                 ...
# 2255  I remember seeing the first one as a kid and I...
# 2256  I totally DID NOT EXPECT THIS THING 0:57 ... n...
# 2257                                                NaN
# 2258  Amazing cast!  Better than the previous ones! ...
# 2259  Acabo de ver la película y me dejo un dolor de...
#
# [2260 rows x 7 columns]

# %%
final_df = pd.merge(youtube,finalmato_df,left_on='MovieTitle',right_on='title',how='inner')

# %%
final_df.drop(columns=['YouTube Video ID','YouTube Video Title'], inplace=True)

# %%
final_df.columns
# Out:
# Index(['MovieTitle', 'Views', 'Likes', 'Comments', 'Top 10 Comments', 'Movie',
#        'Specific Rotten Tomato Score', 'movie', 'gross_earnings_domestic',
#        'theatres', 'earnings_per_theatre', 'id', 'budget', 'genres',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'title', 'keywords', 'cast', 'revenue', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
flattened_languages = set(language for sublist in final_df['spoken_languages'] for language in sublist)

# Convert the set to a list to view the unique elements
unique_languages = list(flattened_languages)

unique_languages
# Out:
# ['',
#  'Íslenska',
#  'Dansk',
#  'suomi',
#  'euskera',
#  'shqip',
#  'Український',
#  'ਪੰਜਾਬੀ',
#  'தமிழ்',
#  'Deutsch',
#  'فارسی',
#  'Cymraeg',
#  'Slovenčina',
#  'Português',
#  'Fulfulde',
#  'עִבְרִית',
#  'हिन्दी',
#  'Bahasa indonesia',
#  'اردو',
#  'Català',
#  'No Language',
#  'Lietuvių',
#  'Polski',
#  'Galego',
#  'Bamanankan',
#  'Magyar',
#  'Somali',
#  'қазақ',
#  'Kiswahili',
#  '한국어/조선말',
#  'Eesti',
#  'Bosanski',
#  'Afrikaans',
#  '普通话',
#  'Français',
#  'Italiano',
#  'svenska',
#  '广州话 / 廣州話',
#  'ελληνικά',
#  'Bahasa melayu',
#  'Nederlands',
#  'Pусский',
#  'Español',
#  '日本語',
#  'বাংলা',
#  'Norsk',
#  'English',
#  'Română',
#  'Latin',
#  'Český',
#  'Tiếng Việt',
#  'ภาษาไทย',
#  'Esperanto',
#  'తెలుగు',
#  'български език',
#  'Hrvatski',
#  'Türkçe',
#  'Gaeilge',
#  'العربية',
#  '?????']
